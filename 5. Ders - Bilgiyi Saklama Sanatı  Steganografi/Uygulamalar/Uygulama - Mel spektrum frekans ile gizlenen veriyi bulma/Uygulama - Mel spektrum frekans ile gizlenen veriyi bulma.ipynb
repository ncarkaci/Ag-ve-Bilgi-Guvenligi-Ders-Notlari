# %% [markdown]
# Spectrum Analizi

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def mel_spectrum_image_of_audio(audio_file, time_width=10):
    """
    Saves the Mel frequency spectrum of an audio file as an image with the same name.

    :param audio_file: Path to the audio file.
    :param time_width: Width of the time axis in the plot (in inches).
    """
    # Generate image file name based on audio file name
    image_file = audio_file.rsplit('.', 1)[0] + '_mel_spectrum.png'

    # Load the audio file
    y, sr = librosa.load(audio_file)

    # Compute the Mel spectrogram
    mel_spect = librosa.feature.melspectrogram(y=y, sr=sr)

    # Convert to dB
    mel_spect_dB = librosa.power_to_db(mel_spect, ref=np.max)

    # Plot
    plt.figure(figsize=(time_width, 4))
    librosa.display.specshow(mel_spect_dB, sr=sr, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel-frequency spectrogram of ' + audio_file)
    plt.tight_layout()

    # Save the plot as an image file
    plt.savefig(image_file)
    plt.close()

    return image_file

# %%
original_audio_file_path = "./Hear with your Eyes.wav"
original_image_file_path = mel_spectrum_image_of_audio(original_audio_file_path)

# %%
from IPython.display import Image as ColabImage
ColabImage(original_image_file_path)

# %%
original_audio_file_path = "./Drawing_of_the_word_Wikipedia_transformed_into_a_wav_file_(Coagula_software).wav"
original_image_file_path = mel_spectrum_image_of_audio(original_audio_file_path)

# %%
from IPython.display import Image as ColabImage
ColabImage(original_image_file_path)

# %%
original_audio_file_path = "./image_to_audio_music.wav"
original_image_file_path = mel_spectrum_image_of_audio(original_audio_file_path)

# %%
from IPython.display import Image as ColabImage
ColabImage(original_image_file_path)

# %%
original_audio_file_path = "./image_to_audio_music.wav"
original_image_file_path = mel_spectrum_image_of_audio(original_audio_file_path, time_width=4)

# %%
from IPython.display import Image as ColabImage
ColabImage(original_image_file_path)

# %%
watermarked_audio_file_path = "./World_On_Fire.wav"
watermarked_image_file_path = mel_spectrum_image_of_audio(watermarked_audio_file_path, time_width=100)

# %%
# make time width 100
watermarked_audio_file_path = "./World_On_Fire.wav"
watermarked_image_file_path = mel_spectrum_image_of_audio(watermarked_audio_file_path,  time_width=100)

# %%
from IPython.display import Image as ColabImage
ColabImage(watermarked_image_file_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
original_audio_file_path = "./mix.mp3"
original_image_file_path = mel_spectrum_image_of_audio(original_audio_file_path)

# %%
from IPython.display import Image as ColabImage
ColabImage(original_image_file_path)

# %%
# make time width 100
original_audio_file_path = "./mix.mp3"
original_image_file_path = mel_spectrum_image_of_audio(original_audio_file_path, time_width=100)

# %%
from IPython.display import Image as ColabImage
ColabImage(original_image_file_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# make time width 500
original_audio_file_path = "./mix.mp3"
original_image_file_path = mel_spectrum_image_of_audio(original_audio_file_path, time_width=500)

# %%
from IPython.display import Image as ColabImage
ColabImage(original_image_file_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
