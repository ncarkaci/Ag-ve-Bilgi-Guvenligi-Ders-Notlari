# %% [markdown]
# ## AMAÇ :

# %% [markdown]
# Bu uygulamanın amacı kişiye resim üzerinde matıksal olarak veri gizleme yöntemlerine dair görüş açısı kazandırmaktır.

# %% [markdown]
# ## SÜRE :

# %% [markdown]
# 5 dakika

# %% [markdown]
# ## ÖNBİLGİ :

# %% [markdown]
# Resim içerisinde yer alan görsel objeler belli anlamlarla eşleştirilerek resim üzerinde gizleme yapılabilmektedir. Örneğin resim içinde yer alan kedinin sağa bakması belli bir anlam ile sola bakması belli bir anlam ile eşleştirilebilir. Daha önceden anlaşılan görsel dil üzerinden herhangi bir kedi resmi ile kolayca mesajlaşılabilmektedir.

# %%
from IPython.display import Image
Image(filename="saga_bakan_kedi.jpg")

# %%
from IPython.display import Image
Image("sola_bakan_kedi.jpg", width=200, height=172)

# %% [markdown]
# ## UYGULAMA :

# %% [markdown]
# ### A. Uygulama öncesi yapılacaklar :

# %% [markdown]
# ### B. Uygulamanın Yapılışı:

# %% [markdown]
# #### a. Resimde gizli mesajı bulun.

# %%
from IPython.display import Image
Image("leonardo.jpg")

# %% [markdown]
# ## ANALİZ :

# %% [markdown]
# ## KAYNAKLAR :
